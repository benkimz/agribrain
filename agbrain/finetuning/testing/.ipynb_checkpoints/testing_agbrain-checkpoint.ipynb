# %%
# !pip install -q transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 70.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 20.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 99.7 MB/s eta 0:00:00

# %%
import tensorflow as tf
from transformers import TFGPT2LMHeadModel, GPT2Tokenizer

# %%
tokenizer = GPT2Tokenizer.from_pretrained("benkimz/agbrain")
model = TFGPT2LMHeadModel.from_pretrained("benkimz/agbrain")
# Out:
# Downloading vocab.json:   0%|          | 0.00/999k [00:00<?, ?B/s]
# Downloading merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/438 [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/722 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/907 [00:00<?, ?B/s]
# Downloading tf_model.h5:   0%|          | 0.00/498M [00:00<?, ?B/s]
# All model checkpoint layers were used when initializing TFGPT2LMHeadModel.
#
# All the layers of TFGPT2LMHeadModel were initialized from the model checkpoint at benkimz/agbrain.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2LMHeadModel for predictions without further training.
# Downloading generation_config.json:   0%|          | 0.00/119 [00:00<?, ?B/s]

# %%
prompt = """
I think agribusiness is a great opportunity for passionate investors. 
From food business to growing crops for sale, and rearing livestock for 
business.
"""

input_ids = tokenizer.encode(prompt, return_tensors="tf")
outputs = model.generate(input_ids=input_ids, max_length=120, do_sample=True)
generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

print(generated_text)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# I think agribusiness is a great opportunity for passionate investors.
# From food business to growing crops for sale, and rearing livestock for
# business.
# Agroecology is a major element in growing land production is land, farming practices
# have to be applied in soil management techniques.
# Many agri-business organizations have been founded to bring
# agriculture to market.  major reason of this success is innovation
# of agroecology in agriculture. It is easy to understand that
# Agroecological movement is changing as an economy advances rapidly,

# %%
from transformers import pipeline, set_seed
generator = pipeline('text-generation', model='benkimz/agbrain')
set_seed(42)
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/510M [00:00<?, ?B/s]

# %%
samples = generator("The most common crop is ", max_length=40, num_return_sequences=2)

for sample in samples:
  print(sample['generated_text'], "\n\n")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The most common crop is  a weed called Aspergillus coelacanth, often sold around North America. These plants have been well appreciated as potential weeds in crop production.  Asper
#
#
# The most common crop is
# favourable sweet
# fruit in China
# smaller sizes such
#  as  is. In China,
# countries such as    be
